# %%
import numpy as np
import pandas as pd
#used to store and echange complex data: allows  you to save python objects and then later load them back into memory
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#import data
data = pd.read_csv("Loan_Default.csv", index_col=0)

# %%
#look at the data and categories
data.head()
# Out:
#        year loan_limit             Gender approv_in_adv loan_type  \
# ID
# 24890  2019         cf  Sex Not Available         nopre     type1
# 24891  2019         cf               Male         nopre     type2
# 24892  2019         cf               Male           pre     type1
# 24893  2019         cf               Male         nopre     type1
# 24894  2019         cf              Joint           pre     type1
#
#       loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# ID
# 24890           p1                l1        nopc                  nob/c
# 24891           p1                l1        nopc                    b/c
# 24892           p1                l1        nopc                  nob/c
# 24893           p4                l1        nopc                  nob/c
# 24894           p1                l1        nopc                  nob/c
#
#        loan_amount  ...  credit_type  Credit_Score  co-applicant_credit_type  \
# ID                  ...
# ...

# %%
#making all variable names lower case for convience
data.columns = data.columns.str.lower()
data.head()
# Out:
#        year loan_limit             gender approv_in_adv loan_type  \
# ID
# 24890  2019         cf  Sex Not Available         nopre     type1
# 24891  2019         cf               Male         nopre     type2
# 24892  2019         cf               Male           pre     type1
# 24893  2019         cf               Male         nopre     type1
# 24894  2019         cf              Joint           pre     type1
#
#       loan_purpose credit_worthiness open_credit business_or_commercial  \
# ID
# 24890           p1                l1        nopc                  nob/c
# 24891           p1                l1        nopc                    b/c
# 24892           p1                l1        nopc                  nob/c
# 24893           p4                l1        nopc                  nob/c
# 24894           p1                l1        nopc                  nob/c
#
#        loan_amount  ...  credit_type  credit_score  co-applicant_credit_type  \
# ID                  ...
# ...

# %%
#look at infor to see columns, couts, and type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148670 entries, 24890 to 173559
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   year                       148670 non-null  int64
#  1   loan_limit                 145326 non-null  object
#  2   gender                     148670 non-null  object
#  3   approv_in_adv              147762 non-null  object
#  4   loan_type                  148670 non-null  object
#  5   loan_purpose               148536 non-null  object
#  6   credit_worthiness          148670 non-null  object
#  7   open_credit                148670 non-null  object
#  8   business_or_commercial     148670 non-null  object
#  9   loan_amount                148670 non-null  int64
#  10  rate_of_interest           112231 non-null  float64
#  11  interest_rate_spread       112031 non-null  float64
#  12  upfront_charges            109028 non-null  float64
# ...

# %%
#look at missing values
data.isnull().sum()
# Out:
# year                             0
# loan_limit                    3344
# gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# credit_worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# interest_rate_spread         36639
# upfront_charges              39642
# term                            41
# neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# credit_score                     0
# co-applicant_credit_type         0
# age                            200
# ...

# %%
#look at the unique factors of status
data['status'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#look at the counts of each category
data['status'].value_counts(dropna=False)
# Out:
# 0    112031
# 1     36639
# Name: status, dtype: int64

# %%
#look at the count of each category for credit score
#there are two many variables to look at them individualy compared to status
#need to bin the variables to analyze them
data['credit_score'].value_counts(dropna=False)
# Out:
# 763    415
# 867    413
# 639    411
# 581    408
# 554    407
#       ...
# 745    330
# 573    330
# 743    327
# 748    324
# 559    321
# Name: credit_score, Length: 401, dtype: int64

# %%
#use groupby and bins to put the credit_score varibles in bins by credit_score range (poor, fair, good, very good, exceptional)
groups = data.groupby(['status', pd.cut(data.credit_score, [300, 579, 669, 739, 799, 850])])

#display bin count grouped by credit score
groups.size().unstack()
# Out:
# credit_score  (300, 579]  (579, 669]  (669, 739]  (739, 799]  (799, 850]
# status
# 0                  22403       25334       19545       16711       14193
# 1                   7334        8214        6228        5432        4744

# %%
# plot the result
groups.size().unstack().plot.bar()
plt.xticks(rotation=45)
plt.title("Count of Credit Score Defaulted or Not Defaulted")
plt.show()

# %%
#put credit_score variable into a bin by credit_score category (poor, fair, good, very good, exceptional).

credit = data['credit_score']
bins = [300, 579, 669, 739, 799, 850]
cats = pd.cut(credit, bins)
cats
# Out:
# ID
# 24890     (739, 799]
# 24891     (300, 579]
# 24892     (799, 850]
# 24893     (579, 669]
# 24894     (579, 669]
#              ...
# 173555    (579, 669]
# 173556    (300, 579]
# 173557    (669, 739]
# 173558    (669, 739]
# 173559    (799, 850]
# Name: credit_score, Length: 148670, dtype: category
# Categories (5, interval[int64, right]): [(300, 579] < (579, 669] < (669, 739] < (739, 799] < (799, 850]]

# %%
# countplot of credit_score categories
plt.figure(figsize = (6,6))
sns.countplot(x = cats, data = data)
plt.title("Count of Credit Score within Categories")
plt.show()
